# %% [markdown]
# # Silhouette Analysis

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import os

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_samples, silhouette_score

import fastf1

# %%
dir = 'C:/Users/perot/Documents/Università/VA/Project/data'
for subdir, dirs, files in os.walk(dir):
    for file in files:
        if file == 'tSNE.csv':
            csv = os.path.join(subdir, file)
            df = pd.read_csv(csv)
            #print(df.info())
            cols = ['dim1', 'dim2']
            X = df[cols]

            range_n_clusters = [2, 3, 4, 5, 6, 7, 8]
            print(subdir+ '\n')
            for n_clusters in range_n_clusters:
                
                # Create a subplot with 1 row and 2 columns
                #fig, (ax1) = plt.subplots(1, 1)
                #fig.set_size_inches(5, 5)

                # The 1st subplot is the silhouette plot
                # The silhouette coefficient can range from -1, 1 
                #ax1.set_xlim([-1, 1])
                # The (n_clusters+1)*10 is for inserting blank space between silhouette
                # plots of individual clusters, to demarcate them clearly.
                #ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

                # Initialize the clusterer with n_clusters value and a random generator
                # seed of 10 for reproducibility.
                clusterer = KMeans(n_clusters=n_clusters, random_state=16)
                cluster_labels = clusterer.fit_predict(X)

                # The silhouette_score gives the average value for all the samples.
                # This gives a perspective into the density and separation of the formed
                # clusters
                silhouette_avg = silhouette_score(X, cluster_labels)
                
                print(
                    "For n_clusters =",
                    n_clusters,
                    "The average silhouette_score is :",
                    silhouette_avg,
                )
                # Compute the silhouette scores for each sample
                sample_silhouette_values = silhouette_samples(X, cluster_labels)

                '''
                y_lower = 10
                for i in range(n_clusters):
                    # Aggregate the silhouette scores for samples belonging to
                    # cluster i, and sort them
                    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

                    ith_cluster_silhouette_values.sort()

                    size_cluster_i = ith_cluster_silhouette_values.shape[0]
                    y_upper = y_lower + size_cluster_i

                    color = cm.nipy_spectral(float(i) / n_clusters)
                    ax1.fill_betweenx(
                        np.arange(y_lower, y_upper),
                        0,
                        ith_cluster_silhouette_values,
                        facecolor=color,
                        edgecolor=color,
                        alpha=0.7,
                        )

                    # Label the silhouette plots with their cluster numbers at the middle
                    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

                    # Compute the new y_lower for next plot
                    y_lower = y_upper + 10  # 10 for the 0 samples

                ax1.set_title("The silhouette plot for the various clusters.")
                ax1.set_xlabel("The silhouette coefficient values")
                ax1.set_ylabel("Cluster label")

                # The vertical line for average silhouette score of all the values
                ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

                ax1.set_yticks([])  # Clear the yaxis labels / ticks
                ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        
            plt.show()
            '''
# Out:
# C:/Users/perot/Documents/Università/VA/Project/data\10_Silverstone
#
# For n_clusters = 2 The average silhouette_score is : 0.5130626050040509
# For n_clusters = 3 The average silhouette_score is : 0.5992060375264444
# For n_clusters = 4 The average silhouette_score is : 0.6006937542870228
# For n_clusters = 5 The average silhouette_score is : 0.5248952301395069
# For n_clusters = 6 The average silhouette_score is : 0.5065895922531308
# For n_clusters = 7 The average silhouette_score is : 0.47786296044120974
# For n_clusters = 8 The average silhouette_score is : 0.4268556266756725
# C:/Users/perot/Documents/Università/VA/Project/data\11_Budapest
#
# For n_clusters = 2 The average silhouette_score is : 0.4137301175059871
# For n_clusters = 3 The average silhouette_score is : 0.522499406395405
# For n_clusters = 4 The average silhouette_score is : 0.44678658424325546
# For n_clusters = 5 The average silhouette_score is : 0.42548655833300025
# For n_clusters = 6 The average silhouette_score is : 0.4141019912306796
# For n_clusters = 7 The average silhouette_score is : 0.43207275683136226
# For n_clusters = 8 The average silhouette_score is : 0.42812719535157084
# C:/Users/perot/Documents/Università/VA/Project/data\12_Spa-Francorchamps
#
# For n_clusters = 2 The average silhouette_score is : 0.45680634108694235
# For n_clusters = 3 The average silhouette_score is : 0.4255852546332793
# For n_clusters = 4 The average silhouette_score is : 0.4500729019019318
# For n_clusters = 5 The average silhouette_score is : 0.4461569954914615
# For n_clusters = 6 The average silhouette_score is : 0.43965344621139724
# For n_clusters = 7 The average silhouette_score is : 0.4150075293731
# For n_clusters = 8 The average silhouette_score is : 0.3941844008741674
# C:/Users/perot/Documents/Università/VA/Project/data\13_Zandvoort
#
# For n_clusters = 2 The average silhouette_score is : 0.5454489243476025
# For n_clusters = 3 The average silhouette_score is : 0.5516182354957841
# For n_clusters = 4 The average silhouette_score is : 0.5958680216040508
# For n_clusters = 5 The average silhouette_score is : 0.5915396375598708
# For n_clusters = 6 The average silhouette_score is : 0.5955086723115411
# For n_clusters = 7 The average silhouette_score is : 0.6048529115674288
# For n_clusters = 8 The average silhouette_score is : 0.5753838435455206
# C:/Users/perot/Documents/Università/VA/Project/data\14_Monza
#
# For n_clusters = 2 The average silhouette_score is : 0.3928904939629544
# For n_clusters = 3 The average silhouette_score is : 0.4445605839839292
# For n_clusters = 4 The average silhouette_score is : 0.4098250849701698
# For n_clusters = 5 The average silhouette_score is : 0.3817023943213615
# For n_clusters = 6 The average silhouette_score is : 0.39107285922546337
# For n_clusters = 7 The average silhouette_score is : 0.35466794393388834
# For n_clusters = 8 The average silhouette_score is : 0.3730814307174227
# C:/Users/perot/Documents/Università/VA/Project/data\15_Marina Bay
#
# For n_clusters = 2 The average silhouette_score is : 0.47379282059623057
# For n_clusters = 3 The average silhouette_score is : 0.44465517252848824
# For n_clusters = 4 The average silhouette_score is : 0.44034995440404984
# For n_clusters = 5 The average silhouette_score is : 0.4006776627177653
# For n_clusters = 6 The average silhouette_score is : 0.39552000360483014
# For n_clusters = 7 The average silhouette_score is : 0.411126668181871
# For n_clusters = 8 The average silhouette_score is : 0.3741483842471141
# C:/Users/perot/Documents/Università/VA/Project/data\16_Suzuka
#
# For n_clusters = 2 The average silhouette_score is : 0.5427444930882613
# For n_clusters = 3 The average silhouette_score is : 0.4204972802047872
# For n_clusters = 4 The average silhouette_score is : 0.43641784453843724
# For n_clusters = 5 The average silhouette_score is : 0.364881448879052
# For n_clusters = 6 The average silhouette_score is : 0.3666194467819309
# For n_clusters = 7 The average silhouette_score is : 0.41960044185567597
# For n_clusters = 8 The average silhouette_score is : 0.3891037845947639
# C:/Users/perot/Documents/Università/VA/Project/data\17_Lusail
#
# For n_clusters = 2 The average silhouette_score is : 0.5194837840768225
# For n_clusters = 3 The average silhouette_score is : 0.4416334437663295
# For n_clusters = 4 The average silhouette_score is : 0.44142298295007193
# For n_clusters = 5 The average silhouette_score is : 0.41300879909258037
# For n_clusters = 6 The average silhouette_score is : 0.4507266762979397
# For n_clusters = 7 The average silhouette_score is : 0.4468718103082139
# For n_clusters = 8 The average silhouette_score is : 0.4137486016284666
# C:/Users/perot/Documents/Università/VA/Project/data\18_Austin
#
# For n_clusters = 2 The average silhouette_score is : 0.4017765260976275
# For n_clusters = 3 The average silhouette_score is : 0.44411457732161763
# For n_clusters = 4 The average silhouette_score is : 0.42351591388159604
# For n_clusters = 5 The average silhouette_score is : 0.4705234075502514
# For n_clusters = 6 The average silhouette_score is : 0.4307014280248261
# For n_clusters = 7 The average silhouette_score is : 0.43349328106800306
# For n_clusters = 8 The average silhouette_score is : 0.43356134936582186
# C:/Users/perot/Documents/Università/VA/Project/data\19_Mexico City
#
# For n_clusters = 2 The average silhouette_score is : 0.610989819522325
# For n_clusters = 3 The average silhouette_score is : 0.4534668307938377
# For n_clusters = 4 The average silhouette_score is : 0.39194534208210974
# For n_clusters = 5 The average silhouette_score is : 0.42534259583328593
# For n_clusters = 6 The average silhouette_score is : 0.39447292416097957
# For n_clusters = 7 The average silhouette_score is : 0.44086387829246293
# For n_clusters = 8 The average silhouette_score is : 0.47065390223458403
# C:/Users/perot/Documents/Università/VA/Project/data\1_Sakhir
#
# For n_clusters = 2 The average silhouette_score is : 0.5134692133489539
# For n_clusters = 3 The average silhouette_score is : 0.39107772077372865
# For n_clusters = 4 The average silhouette_score is : 0.41507633940617966
# For n_clusters = 5 The average silhouette_score is : 0.4837820765951403
# For n_clusters = 6 The average silhouette_score is : 0.4514834014459628
# For n_clusters = 7 The average silhouette_score is : 0.40383955801205723
# For n_clusters = 8 The average silhouette_score is : 0.41719313922162826
# C:/Users/perot/Documents/Università/VA/Project/data\20_São Paulo
#
# For n_clusters = 2 The average silhouette_score is : 0.4932415347124662
# For n_clusters = 3 The average silhouette_score is : 0.47183628286352425
# For n_clusters = 4 The average silhouette_score is : 0.5070145625216743
# For n_clusters = 5 The average silhouette_score is : 0.4851008758941102
# For n_clusters = 6 The average silhouette_score is : 0.4867472691257211
# For n_clusters = 7 The average silhouette_score is : 0.4828420477343393
# For n_clusters = 8 The average silhouette_score is : 0.4710512752201508
# C:/Users/perot/Documents/Università/VA/Project/data\21_Las Vegas
#
# For n_clusters = 2 The average silhouette_score is : 0.45730248925337
# For n_clusters = 3 The average silhouette_score is : 0.4287893904436174
# For n_clusters = 4 The average silhouette_score is : 0.4365635169165339
# For n_clusters = 5 The average silhouette_score is : 0.4087427451720425
# For n_clusters = 6 The average silhouette_score is : 0.4247397243159624
# For n_clusters = 7 The average silhouette_score is : 0.4064255374039205
# For n_clusters = 8 The average silhouette_score is : 0.4199985181596473
# C:/Users/perot/Documents/Università/VA/Project/data\22_Yas Island
#
# For n_clusters = 2 The average silhouette_score is : 0.5000623859865408
# For n_clusters = 3 The average silhouette_score is : 0.4437152532594142
# For n_clusters = 4 The average silhouette_score is : 0.4394118413878358
# For n_clusters = 5 The average silhouette_score is : 0.4003032965590283
# For n_clusters = 6 The average silhouette_score is : 0.3990313299287271
# For n_clusters = 7 The average silhouette_score is : 0.4291715841458955
# For n_clusters = 8 The average silhouette_score is : 0.4035471562269484
# C:/Users/perot/Documents/Università/VA/Project/data\2_Jeddah
#
# For n_clusters = 2 The average silhouette_score is : 0.4715014723952299
# For n_clusters = 3 The average silhouette_score is : 0.44724906238559375
# For n_clusters = 4 The average silhouette_score is : 0.44681774315758765
# For n_clusters = 5 The average silhouette_score is : 0.3905467257589569
# For n_clusters = 6 The average silhouette_score is : 0.4429365115925029
# For n_clusters = 7 The average silhouette_score is : 0.44406520511553044
# For n_clusters = 8 The average silhouette_score is : 0.4160773512363167
# C:/Users/perot/Documents/Università/VA/Project/data\3_Melbourne
#
# For n_clusters = 2 The average silhouette_score is : 0.47925848439338953
# For n_clusters = 3 The average silhouette_score is : 0.4589737906287536
# For n_clusters = 4 The average silhouette_score is : 0.4426045268006729
# For n_clusters = 5 The average silhouette_score is : 0.4580962898220564
# For n_clusters = 6 The average silhouette_score is : 0.4713164888651142
# For n_clusters = 7 The average silhouette_score is : 0.480896601541946
# For n_clusters = 8 The average silhouette_score is : 0.4223311285222272
# C:/Users/perot/Documents/Università/VA/Project/data\4_Baku
#
# For n_clusters = 2 The average silhouette_score is : 0.44726675512478425
# For n_clusters = 3 The average silhouette_score is : 0.4595098536898829
# For n_clusters = 4 The average silhouette_score is : 0.4812247910698187
# For n_clusters = 5 The average silhouette_score is : 0.43445628463704156
# For n_clusters = 6 The average silhouette_score is : 0.41835130812220167
# For n_clusters = 7 The average silhouette_score is : 0.41401793144613064
# For n_clusters = 8 The average silhouette_score is : 0.4059002479226458
# C:/Users/perot/Documents/Università/VA/Project/data\5_Miami
#
# For n_clusters = 2 The average silhouette_score is : 0.47933758300228607
# For n_clusters = 3 The average silhouette_score is : 0.39184224966086406
# For n_clusters = 4 The average silhouette_score is : 0.45434438022186663
# For n_clusters = 5 The average silhouette_score is : 0.41597567342568986
# For n_clusters = 6 The average silhouette_score is : 0.4217879604975759
# For n_clusters = 7 The average silhouette_score is : 0.40360675135517443
# For n_clusters = 8 The average silhouette_score is : 0.3991720672812316
# C:/Users/perot/Documents/Università/VA/Project/data\6_Monaco
#
# For n_clusters = 2 The average silhouette_score is : 0.6559879739571602
# For n_clusters = 3 The average silhouette_score is : 0.5108667681506116
# For n_clusters = 4 The average silhouette_score is : 0.5074602140957488
# For n_clusters = 5 The average silhouette_score is : 0.48860377205246563
# For n_clusters = 6 The average silhouette_score is : 0.49332931928526597
# For n_clusters = 7 The average silhouette_score is : 0.4643288257145832
# For n_clusters = 8 The average silhouette_score is : 0.4598228777184272
# C:/Users/perot/Documents/Università/VA/Project/data\7_Barcelona
#
# For n_clusters = 2 The average silhouette_score is : 0.4178083532007609
# For n_clusters = 3 The average silhouette_score is : 0.4385619880197678
# For n_clusters = 4 The average silhouette_score is : 0.4336581574458577
# For n_clusters = 5 The average silhouette_score is : 0.4209902855116904
# For n_clusters = 6 The average silhouette_score is : 0.3908050202735059
# For n_clusters = 7 The average silhouette_score is : 0.4371254369445868
# For n_clusters = 8 The average silhouette_score is : 0.4735522328513642
# C:/Users/perot/Documents/Università/VA/Project/data\8_Montréal
#
# For n_clusters = 2 The average silhouette_score is : 0.4950825842326198
# For n_clusters = 3 The average silhouette_score is : 0.4117961174718459
# For n_clusters = 4 The average silhouette_score is : 0.45300360837992537
# For n_clusters = 5 The average silhouette_score is : 0.42238377492707924
# For n_clusters = 6 The average silhouette_score is : 0.4159851471647215
# For n_clusters = 7 The average silhouette_score is : 0.4255012896368072
# For n_clusters = 8 The average silhouette_score is : 0.4170791694869477
# C:/Users/perot/Documents/Università/VA/Project/data\9_Spielberg
#
# For n_clusters = 2 The average silhouette_score is : 0.4772205235042824
# For n_clusters = 3 The average silhouette_score is : 0.40234218261136406
# For n_clusters = 4 The average silhouette_score is : 0.39926568485981745
# For n_clusters = 5 The average silhouette_score is : 0.4109039655037197
# For n_clusters = 6 The average silhouette_score is : 0.4167509241492328
# For n_clusters = 7 The average silhouette_score is : 0.4015378142778269
# For n_clusters = 8 The average silhouette_score is : 0.3827619750153823
